# %%
import os
import pandas as pd
import numpy as np
import  utils.Data_preprocessing as dp
from utils.EDA import EDA 

import matplotlib.pyplot as plt
# %matplotlib inline


import gc
gc.enable()
PATH = '../input/'
Processed = '../input/processed/'
directory = os.path.dirname(Processed)
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
application_df = pd.read_csv(Processed+"application.csv")

# %%
eda = EDA(application_df)
eda.explore()
# Out:
# ******************************************************************************************************************
# ******************************************************************************************************************
#      COLUMN==> AMT_ANNUITY
# ******************************************************************************************************************
# ******************************************************************************************************************
# --------------------------------------
# Data Type: number
#
# --------------------------------------
# Describe:
#
# count    356255.000000
# mean      27422.789270
# std       14734.642945
# min           0.000000
# 25%       16722.000000
# 50%       25078.500000
# 75%       34960.500000
# max      258025.500000
# Name: AMT_ANNUITY, dtype: float64
# --------------------------------------
# excess kurtosis of normal distribution (should be 0): 7.232774424932
# ...

# %%
application_df.shape
# Out:
# (356255, 122)

# %%
#one hot encoding
cat_feat=dp.get_categorical_features(application_df)
application_df=dp.onehot_encoding(application_df,cat_feat)
application_df.shape
# Out:
# (356255, 230)

# %%
# Out:
# []
